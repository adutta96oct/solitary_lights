# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(0,5,11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y)
plt.xlabel('xlabel')
plt.ylabel('ylabel')
plt.title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
plt.subplot(1,2,1)
plt.plot(x,y, 'r-')

plt.subplot(1,2,2)
plt.plot(y,x, 'b' )

# %%
# OO method of visualization
fig = plt.figure()

axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y)

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.5,0.1,0.4,0.4])

axes2.plot(y,x, 'r-')
axes2.set_title('smaller plot')
axes1.plot(x,y)
axes1.set_title('larger plot')
# Out:
# Text(0.5, 1.0, 'larger plot')

# %%
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(5,5))
ax[0].plot(x,y)
ax[1].plot(y,x, 'r-')
plt.tight_layout()

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(5,5))
ax.plot(x,x**2, label='X squared', linewidth=5, ls='-', marker='+', markersize=15, markeredgecolor='#a63636', markeredgewidth=3)
ax.plot(x,x**3, label='X cubed', color='#a63636', ls='--', marker='o', markerfacecolor='yellow', markersize=10, markeredgecolor='blue')
ax.legend(loc='upper left')

ax.set_xlim([0,3])
ax.set_ylim([0,30])
# Out:
# (0.0, 30.0)

# %% [markdown]
# Some Exercises regarding Matplotlib

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('x vs y')
# Out:
# Text(0.5, 1.0, 'x vs y')

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2, 0.5,0.2, 0.2])

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2, 0.5,0.2, 0.2])
ax1.plot(x,y,'r-')
ax2.plot(x,y, 'r-')

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2, 0.5,0.4, 0.4])

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2, 0.5,0.4, 0.4])
ax1.plot(x,z)
ax2.plot(x,y)

ax1.set_xlabel('x')
ax1.set_ylabel('z')
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.set_title('zoom')


ax1.set_xlim([0,100])
ax1.set_ylim([0,10000])
ax2.set_xlim([20,22])
ax2.set_ylim([30,50])
# Out:
# (30.0, 50.0)

# %%
fig,ax = plt.subplots(1,2, figsize=(10,2))
ax[0].plot(x,y, color='blue', ls='--', lw=3)
ax[1].plot(x,y, color='red', lw=3)
